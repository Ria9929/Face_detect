# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=plt.imread('/content/article-2710871-1BFBE72900000578-33_634x356.jpg')

# %%
img.shape
# Out:
# (356, 634, 3)

# %%
import cv2

# %%
model = cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces
# Out:
# array([[288,  35,  62,  62],
#        [367,   1,  66,  66],
#        [210,  32,  74,  74],
#        [ 39,  45,  93,  93],
#        [134, 115,  95,  95],
#        [198, 145, 105, 105],
#        [299, 148, 154, 154]], dtype=int32)

# %%
faces.shape
# Out:
# (7, 4)

# %%
for face in faces:
  x,y,w,h = face

  img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,0,0), 2 )

# %%
plt.imshow(img)
